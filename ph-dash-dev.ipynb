# %% [markdown]
# # Notebook setup and Github setup
# 2022/04/22

# %%
# from google.colab import drive

# %%
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Github
# Out:
# /content/drive/MyDrive/Github

# %%
# !git init ph-dash-dev
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Github/ph-dash-dev/.git/

# %%
# %cd ph-dash-dev
# Out:
# /content/drive/MyDrive/Github/ph-dash-dev

# %%
# %ls -a
# Out:
# .git/

# %%
# username = 'hluling'
# git_token = 'hidden'
# repository = 'ph-dash-dev'

# %%
# !git remote add origin https://{git_token}@github.com/{username}/{repository}.git

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/hluling/ph-dash-dev.git (fetch)
# origin	https://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@github.com/hluling/ph-dash-dev.git (push)

# %%
#!git add .

# %%
# !git commit -m 'repo setup'
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@b56554bfdff4.(none)')

# %%
# !git config --global user.email "hluling@outlook.com"

# %%
# !git commit -m 'repo setup'
# Out:
# [master (root-commit) a350f24] repo setup
#  1 file changed, 1 insertion(+)
#  create mode 100644 ph-dash-dev.ipynb

# %%
# !git push -u origin master
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 2.38 KiB | 610.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/hluling/ph-dash-dev.git
#  * [new branch]      master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %% [markdown]
# # Project code starts from here:
