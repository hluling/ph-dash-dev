# %% [markdown]
# # Notebook setup and Github setup
# 2022/04/22

# %%
# from google.colab import drive

# %%
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Github
# Out:
# /content/drive/MyDrive/Github

# %%
# !git init ph-dash-dev
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Github/ph-dash-dev/.git/

# %%
# %cd ph-dash-dev
# Out:
# /content/drive/MyDrive/Github/ph-dash-dev

# %%
# %ls -a
# Out:
# .git/

# %%
# !git remote add origin https://github.com/hluling/ph-dash-dev

# %%
#!git add .

# %%
# !git commit -m 'repo setup'

# %%
# !git config --global user.email "hluling@outlook.com"

# %%
# !git push -u origin master

# %% [markdown]
# # Project code starts from here:

# %% [markdown]
# # For pushing changes

# %%
# !git add .

# %%
# !git commit -m 'repo setup'
# Out:
# [master b52dbab] repo setup
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite ph-dash-dev.ipynb (97%)

# %%
# !git push -u origin master
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
# !gh auth login
# Out:
# 78? What account do you want to log into?  [Use arrows to move, type to filter]
# > GitHub.com
#   GitHub Enterprise Server
# 7^C

# %%
# !git config --global 'credential.https://github.com' '!gh auth git-credential'

# %%
# !git config --global 'credential.https://github.com' '!gh auth git-credential'

# %%
# !git push
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
# !git config --global 'credential.https://github.com'
# Out:
# !gh auth git-credential

# %%
# !gh auth git-credential
# Out:
# accepts 1 arg(s), received 0
